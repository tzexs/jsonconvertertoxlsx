# %%
import json
import pandas as pd

# %%
with open("Downloads/movements.json", encoding=' utf-8') as meu_json:
    dados = json.load(meu_json)

print(dados)
# Out:
# [{'dataOperacao': '2021-07-05', 'descricao': 'dolor aliquip laborum', 'montante': 463.08}, {'dataOperacao': '2015-11-23', 'descricao': 'nostrud ipsum dolore', 'montante': 443.45}, {'dataOperacao': '2019-10-05', 'descricao': 'irure fugiat magna', 'montante': 5.38}, {'dataOperacao': '2015-02-27', 'descricao': 'laboris irure qui', 'montante': 686.16}, {'dataOperacao': '2016-07-14', 'descricao': 'sint ad proident', 'montante': 879.13}, {'dataOperacao': '2021-09-19', 'descricao': 'ad proident aliqua', 'montante': 606.61}, {'dataOperacao': '2021-08-05', 'descricao': 'aliquip culpa dolore', 'montante': 542.44}, {'dataOperacao': '2015-11-27', 'descricao': 'tempor laborum reprehenderit', 'montante': 208.61}, {'dataOperacao': '2017-02-10', 'descricao': 'qui incididunt laborum', 'montante': 38.77}, {'dataOperacao': '2014-06-27', 'descricao': 'proident aliquip ea', 'montante': 171.35}, {'dataOperacao': '2014-01-23', 'descricao': 'eu magna id', 'montante': 67.93}, {'dataOperacao': '2016-11-17', '
# ...

# %%
df = pd.DataFrame(dados)

# %%
df.to_excel("dados.xlsx",index = None, header = False, encoding = 'utf-8')
